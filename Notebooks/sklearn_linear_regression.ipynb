# %% [markdown]
# # Importing Libraries

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
data = fetch_california_housing()
df = pd.DataFrame(data.data, columns=data.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %% [markdown]
# ## another way to load dataset

# %%
data1 = fetch_california_housing(as_frame=True)
df1 = data1.frame

# %%
df["Target"] = data.target

# %%
X = df.drop("Target", axis=1)
y = df["Target"]
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 10870  3.6875      36.0  3.852174   1.017391       577.0  5.017391     33.72
# 11561  1.9439      17.0  3.640916   1.054363      1468.0  2.100143     33.76
# 20386  3.8860      17.0  4.701975   1.087971      1655.0  2.971275     34.20
# 15835  3.7545      52.0  5.242775   1.119461      1043.0  2.009634     37.75
# 4514   2.0700      52.0  4.205387   1.033670      1223.0  4.117845     34.04
# ...       ...       ...       ...        ...         ...       ...       ...
# 3742   2.4167      36.0  4.732984   1.000000       627.0  3.282723     34.19
# 3870   4.3839      26.0  4.718519   1.198148      1098.0  2.033333     34.16
# 9749   2.2667      12.0  3.436242   0.966443       767.0  5.147651     36.69
# 3477   7.5078      24.0  7.022857   0.992000      2710.0  3.097143     34.30
# 13051  3.9727      17.0  5.745231   1.048749      6544.0  2.774057     38.61
#
#        Longitude
# 10870    -117.90
# 11561    -117.99
# 20386    -118.93
# 15835    -122.43
# 4514     -118.20
# ...          ...
# 3742     -118.39
# 3870     -118.46
# 9749     -121.62
# 3477     -118.51
# 13051    -121.29
#
# [16512 rows x 8 columns]

# %% [markdown]
# # Load Model

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predictions

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1.8326827 , 2.65161672, 2.06461516, ..., 0.34031361, 1.20044869,
#        3.15193333])

# %% [markdown]
# # Evaluation

# %%
print("R^2 Score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# R^2 Score: 0.6000775753666345
# MSE: 0.5330667378622986

# %% [markdown]
# # Ploting

# %%
# Plot predictions
plt.figure(figsize=(8,5))
sns.scatterplot(x=y_test, y=y_pred,color='purple')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()
